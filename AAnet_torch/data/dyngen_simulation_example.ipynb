# %%
import dyngen_utils

# %%
dyngen_utils.install(lib_loc='~/software/R/library', verbose=False)
# Out:
# Installing package in: ~/software/R/library
# R[write to console]: Loading required package: remotes

# %%
dyngen_utils.get_backbones(lib_loc='~/software/R/library')
# Out:
# array(['bifurcating', 'bifurcating_converging', 'bifurcating_cycle',
#        'bifurcating_loop', 'binary_tree', 'branching',
#        'consecutive_bifurcating', 'converging', 'cycle', 'cycle_simple',
#        'disconnected', 'linear', 'linear_simple', 'trifurcating'],
#       dtype='<U23')

# %%
backbone = 'bifurcating'
data_cell_info, data_expression = dyngen_utils.generate_dataset(backbone=backbone, lib_loc='~/software/R/library')
# Out:
# Run Parameters:
# 	Backbone:  bifurcating
# 	Number of Cells:  500
# 	Number of TFs:  100
# 	Number of Targets:  50
# 	Number of HKs:  25
# Generating TF network
# Sampling feature network from real network
# Generating kinetics for 175 features
# Generating formulae
# Generating gold standard mod changes
# Precompiling reactions for gold standard
# Running gold simulations
# ...

# %%
data_cell_info
# Out:
#      cell_id  step_ix  simulation_i    sim_time  num_molecules      mult  \
# 1      cell1     2730            30  130.083333      5651868.0  0.854729
# 2      cell2     1068            12  250.000000      5798384.0  1.234719
# 3      cell3     2354            26   90.083333      5688929.0  0.780281
# 4      cell4     1831            20  440.083333      6955417.0  2.145687
# 5      cell5     2444            27   60.000000      5594714.0  0.515414
# ..       ...      ...           ...         ...            ...       ...
# 496  cell496      423             5  310.083333      5629836.0  2.197818
# 497  cell497      432             5  400.083333      5493297.0  2.538605
# 498  cell498     1464            16  490.083333      7991997.0  2.114150
# 499  cell499     1043            12    0.000000      5300501.0  0.474905
# 500  cell500     1084            12  410.083333      6899120.0  0.707678
#
#        lib_size
# 1     4491286.0
# 2     5399109.0
# 3     4770219.0
# 4    11709970.0
# ...

# %%
data_expression
# Out:
#          Burn1_TF1  Burn1_TF2  Burn1_TF3  Burn1_TF4  Burn2_TF1  Burn2_TF2  \
# cell1     6.044394   5.459432   6.087463   6.781360   5.357552   6.357552
# cell2     6.247928   5.781360   6.741467   7.033423   4.807355   6.599913
# cell3     6.523562   6.000000   6.285402   6.807355   5.129283   6.554589
# cell4     6.820179   6.643856   7.665336   8.005625   5.700440   7.409391
# cell5     6.554589   5.426265   6.491853   6.339850   4.643856   5.781360
# ...            ...        ...        ...        ...        ...        ...
# cell496   6.129283   5.584963   6.442943   6.584963   4.906891   6.392317
# cell497   5.857981   5.209453   5.857981   6.149747   3.459432   6.149747
# cell498   6.832890   6.584963   7.741467   7.936638   6.339850   7.679480
# cell499   4.857981   4.754888   5.129283   5.977280   4.392317   5.459432
# cell500   7.087463   6.247928   7.546894   7.714246   6.266787   7.622052
#
#          Burn2_TF3  Burn2_TF4  Burn3_TF1  Burn3_TF2  ...      HK16      HK17  \
# ...
