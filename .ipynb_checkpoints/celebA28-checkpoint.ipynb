# %%
import AAnet
import network
import numpy as np
import AAtools
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline
import tensorflow as tf
import time
import pickle
from sklearn.decomposition import PCA
from PCHA import PCHA
from scipy.spatial import procrustes
import spams as sp
import NMF as nmf
import time
from sklearn.manifold import MDS
import phate
from sklearn.cluster import KMeans
from sklearn.decomposition import NMF

# %%
data = pickle.load(open('/home/dv292/Sync/projects/AAnet/AAnet/data/celeba_28_100k.pkl', 'rb'))
D = 28
data = np.reshape(data, [-1, D*D*3])
data = data / 255
data = (data * 2) - 1 # norm for tanh

# %%
# AAnet params
num_at = 50
noise_z_std = 0.0
act_out = tf.nn.tanh

# %%
# network
enc_net = network.CelebA28ConvEncoder(num_at=num_at)
dec_net = network.CelebA28ConvDecoder(noise_z_std=noise_z_std, act_out=act_out)
model = AAnet.AAnet(enc_net, dec_net)

# %%
model.train(data, batch_size=256, num_batches=10000)
# Out:
# Iter [       0] Time [0.0301] loss [0.1849]
# Iter [     500] Time [2.4049] loss [0.1812]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-26db144e77d4> in <module>()
# ----> 1 model.train(data, batch_size=64, num_batches=10000)
#
# ~/Sync/projects/AAnet/AAnet/AAnet.py in train(self, data, batch_size, num_batches, verbose, min_loss, cond)
#     272             # else:
#     273             #     bc = cond[idx,:]
# --> 274             self.sess.run(self.ae_adam, feed_dict={self.x: bx, self.is_training: 1})
#     275
#     276             if verbose and (t % 500 == 0 or t+1 == num_batches):
#
# /usr/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# ...

# %%
AT_aanet = model.get_ats_x()

# %%
AAtools.plot_celeba(AT_aanet, nc=10)

# %%
# PCA on ats
pca = PCA(n_components=2)
Y_pca_at = pca.fit_transform(AT_aanet)
Y_pca = pca.transform(data)

fig, ax = plt.subplots(1, figsize=(8,6))
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.scatter(Y_pca[:,0], Y_pca[:,1], s=.1, alpha=0.5)
ax.scatter(Y_pca_at[:,0], Y_pca_at[:,1], s=100, c='r')
for i in range(Y_pca_at.shape[0]):
    ax.text(Y_pca_at[i,0], Y_pca_at[i,1], i+1, horizontalalignment='center', verticalalignment='center', 
             fontdict={'color': 'white','size':8,'weight':'bold'})

# %%
# PCA on data
pca = PCA(n_components=2)
Y_pca = pca.fit_transform(data)
Y_pca_at = pca.transform(AT_aanet)

fig, ax = plt.subplots(1, figsize=(8,6))
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.scatter(Y_pca[:,0], Y_pca[:,1], s=.1, alpha=0.5)
ax.scatter(Y_pca_at[:,0], Y_pca_at[:,1], s=100, c='r')
for i in range(Y_pca_at.shape[0]):
    ax.text(Y_pca_at[i,0], Y_pca_at[i,1], i+1, horizontalalignment='center', verticalalignment='center', 
             fontdict={'color': 'white','size':8,'weight':'bold'})

# %%
# PCA on Z data
pca = PCA(n_components=2)
Z_at = np.eye(num_at)
samples_Z = model.data2at(data)
Y_pca = pca.fit_transform(samples_Z)
Y_pca_at = pca.transform(Z_at)

fig, ax = plt.subplots(1, figsize=(8,6))
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.scatter(Y_pca[:,0], Y_pca[:,1], s=.1, alpha=0.5)
ax.scatter(Y_pca_at[:,0], Y_pca_at[:,1], s=100, c='r')
for i in range(Y_pca_at.shape[0]):
    ax.text(Y_pca_at[i,0], Y_pca_at[i,1], i+1, horizontalalignment='center', verticalalignment='center', 
             fontdict={'color': 'white','size':8,'weight':'bold'})

# %%
# PCA on Z AT
pca = PCA(n_components=2)
Z_at = np.eye(num_at)
samples_Z = model.data2at(data)
Y_pca_at = pca.fit_transform(Z_at)
Y_pca = pca.transform(samples_Z)

fig, ax = plt.subplots(1, figsize=(8,6))
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.scatter(Y_pca[:,0], Y_pca[:,1], s=.1, alpha=0.5)
ax.scatter(Y_pca_at[:,0], Y_pca_at[:,1], s=100, c='r')
for i in range(Y_pca_at.shape[0]):
    ax.text(Y_pca_at[i,0], Y_pca_at[i,1], i+1, horizontalalignment='center', verticalalignment='center', 
             fontdict={'color': 'white','size':8,'weight':'bold'})
