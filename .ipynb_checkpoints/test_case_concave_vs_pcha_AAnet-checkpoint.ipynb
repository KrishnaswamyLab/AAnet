# %%
import AAnet
import network
import numpy as np
import AAtools
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline
import tensorflow as tf
import time
import pickle
from sklearn.decomposition import PCA
from PCHA import PCHA
from scipy.spatial import procrustes
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# params fake data
n = 10000
nat = 3
ndim = 100

# %%
# params AAnet
num_at = nat
noise_z_std = 0.04
z_dim = [100,100,100]
#z_dim = [] # linear AA
#act_out = tf.nn.tanh
act_out = None # linear last layer
input_dim = ndim

# %%
# network
enc_net = network.Encoder(num_at=num_at, z_dim=z_dim)
dec_net = network.Decoder(x_dim=input_dim, noise_z_std=noise_z_std, z_dim=z_dim, act_out=act_out)
model = AAnet.AAnet(enc_net, dec_net)

# %%
# fake data
z = np.random.uniform(size=[n,nat])
z = np.log(z)
z = z / np.sum(z, axis=1, keepdims=True)
at = np.random.uniform(size=[nat,ndim])

# %%
exp_vec = np.linspace(1, 0.01, 16)
i = 0
mse_vec_aanet = []
mse_vec_pcha = []
at_list_aanet = []
at_list_pcha = []
for exp_val in exp_vec:
    print('i = %d, exp_val = %f' % (i,exp_val))
    z_concave = z**exp_val
    data = z_concave @ at
    # AAnet
    model.train(data, batch_size=128, num_batches=300)
    AAnet_at = model.get_ats_x()
    _,_,MSE_AAnet = procrustes(AAnet_at.T, at.T)
    at_list_aanet.append(AAnet_at)
    print('MSE AAnet = %f' % MSE_AAnet)
    mse_vec_aanet.append(MSE_AAnet)
    # PCHA
    XC, _, _, _, _ = PCHA(data.T, noc=nat)
    _,_,MSE_PCHA = procrustes(XC, at.T)
    print('MSE PCHA = %f' % MSE_PCHA)
    at_list_pcha.append(XC.T)
    mse_vec_pcha.append(MSE_PCHA)
    i = i + 1
# Out:
# i = 0, exp_val = 1.000000
# Iter [       0] Time [0.0048] loss [0.9508]
# Iter [     299] Time [0.8015] loss [0.0003]
# done.
# MSE AAnet = 0.029003
# MSE PCHA = 0.000044
# i = 1, exp_val = 0.934000
# Iter [       0] Time [0.0043] loss [0.0016]
# Iter [     299] Time [0.7222] loss [0.0000]
# done.
# MSE AAnet = 0.002590
# MSE PCHA = 0.017540
# i = 2, exp_val = 0.868000
# Iter [       0] Time [0.0049] loss [0.0010]
# Iter [     299] Time [0.7271] loss [0.0001]
# done.
# MSE AAnet = 0.009575
# MSE PCHA = 0.046325
# i = 3, exp_val = 0.802000
# Iter [       0] Time [0.0043] loss [0.0004]
# Iter [     299] Time [0.7377] loss [0.0001]
# done.
# MSE AAnet = 0.005325
# MSE PCHA = 0.078218
# i = 4, exp_val = 0.736000
# Iter [       0] Time [0.0048] loss [0.0005]
# Iter [     299] Time [0.9557] loss [0.0001]
# done.
# MSE AAnet = 0.005281
# MSE PCHA = 0.111505
# i = 5, exp_val = 0.670000
# Iter [       0] Time [0.0049] loss [0.0005]
# Iter [     299] Time [0.8009] loss [0.0001]
# done.
# MSE AAnet = 0.004856
# MSE PCHA = 0.145476
# i = 6, exp_val = 0.604000
# Iter [       0] Time [0.0058] loss [0.0010]
# Iter [     299] Time [0.8411] loss [0.0001]
# done.
# MSE AAnet = 0.002127
# MSE PCHA = 0.179950
# i = 7, exp_val = 0.538000
# Iter [       0] Time [0.0052] loss [0.0010]
# Iter [     299] Time [0.7333] loss [0.0001]
# done.
# MSE AAnet = 0.002134
# MSE PCHA = 0.211256
# i = 8, exp_val = 0.472000
# Iter [       0] Time [0.0049] loss [0.0010]
# Iter [     299] Time [0.7119] loss [0.0002]
# done.
# MSE AAnet = 0.008242
# MSE PCHA = 0.228254
# i = 9, exp_val = 0.406000
# Iter [       0] Time [0.0048] loss [0.0011]
# Iter [     299] Time [0.7135] loss [0.0003]
# done.
# MSE AAnet = 0.015721
# MSE PCHA = 0.281417
# i = 10, exp_val = 0.340000
# Iter [       0] Time [0.0050] loss [0.0017]
# Iter [     299] Time [0.7166] loss [0.0003]
# done.
# MSE AAnet = 0.033312
# MSE PCHA = 0.316715
# i = 11, exp_val = 0.274000
# Iter [       0] Time [0.0048] loss [0.0015]
# Iter [     299] Time [0.7182] loss [0.0008]
# done.
# MSE AAnet = 0.071488
# MSE PCHA = 0.339493
# i = 12, exp_val = 0.208000
# Iter [       0] Time [0.0050] loss [0.0015]
# Iter [     299] Time [0.7195] loss [0.0003]
# done.
# MSE AAnet = 0.142074
# MSE PCHA = 0.367783
# i = 13, exp_val = 0.142000
# Iter [       0] Time [0.0050] loss [0.0021]
# Iter [     299] Time [0.7544] loss [0.0003]
# done.
# MSE AAnet = 0.238247
# MSE PCHA = 0.414289
# i = 14, exp_val = 0.076000
# Iter [       0] Time [0.0056] loss [0.0035]
# Iter [     299] Time [0.8100] loss [0.0004]
# done.
# MSE AAnet = 0.368325
# MSE PCHA = 0.486858
# i = 15, exp_val = 0.010000
# Iter [       0] Time [0.0047] loss [0.0048]
# Iter [     299] Time [0.6955] loss [0.0001]
# done.
# MSE AAnet = 0.563274
# MSE PCHA = 0.607027

# %%
plt.plot(1-exp_vec, mse_vec_pcha, label='PCHA', marker='o')
plt.plot(1-exp_vec, mse_vec_aanet, label='AAnet', marker='o')
plt.xlabel('concavity')
plt.ylabel('error')
plt.legend()
plt.show()

# %%
at_array_pcha = np.asarray(at_list_pcha)
at_array_aanet = np.asarray(at_list_aanet)
pca = PCA(n_components=2)
plt.figure(figsize=(20,3))
Y_pca = pca.fit_transform(z @ at)
for i in range(len(exp_vec)):
    exp_val = exp_vec[i]
    z_concave = z**exp_val
    data = z_concave @ at
    AT_curr_pcha = at_array_pcha[i,:,:]
    AT_curr_aanet = at_array_aanet[i,:,:]
    Y_pca_pcha = pca.transform(AT_curr_pcha)
    Y_pca_aanet = pca.transform(AT_curr_aanet)
    # plot PCHA
    plt.subplot(2,16,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.scatter(Y_pca[:,0], Y_pca[:,1], s=1)
    plt.scatter(Y_pca_pcha[:,0], Y_pca_pcha[:,1], s=10, c='r')
    # plot AAnet
    plt.subplot(2,16,i+1+16)
    plt.xticks([])
    plt.yticks([])
    plt.scatter(Y_pca[:,0], Y_pca[:,1], s=1)
    plt.scatter(Y_pca_aanet[:,0], Y_pca_aanet[:,1], s=10, c='r')
plt.show()
