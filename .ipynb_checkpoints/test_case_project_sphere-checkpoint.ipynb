# %%
import AAnet
import network
import numpy as np
import AAtools
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline
import tensorflow as tf
import time
import pickle
from sklearn.decomposition import PCA

# %%
def sample_at_uniform(num_at, n):
    u = np.random.uniform(0,1,[n,num_at])
    e = -np.log(u)
    x = e / np.sum(e, axis=1, keepdims=True)
    return x

# %%
n = 10000
nat = 3
ndim = 100
z = sample_at_uniform(nat, n)
z = z**0.5
at = np.random.uniform(size=[nat,ndim])
data = z @ at

data.shape
# Out:
# (10000, 100)

# %%
np.min(data)
# Out:
# 0.0065838528098547495

# %%
np.max(data)
# Out:
# 0.9986796056754957

# %%
pca = PCA(n_components=ndim)
Y_pca = pca.fit_transform(data)
Y_pca_at = pca.transform(at)

# %%
# plot PCA
plt.scatter(Y_pca[:,0], Y_pca[:,1], s=1)
plt.scatter(Y_pca_at[:,0], Y_pca_at[:,1], s=100, c='r')
plt.show()

# %%
# params
num_at = 3
noise_z_std = 0.03
z_dim = [100,100]
#z_dim = [] # linear AA
act_out = tf.nn.tanh
#act_out = None # linear last layer
input_dim = data.shape[1]

# %%
# network
enc_net = network.Encoder(num_at=num_at, z_dim=z_dim)
dec_net = network.Decoder(x_dim=input_dim, noise_z_std=noise_z_std, z_dim=z_dim, act_out=act_out)
model = AAnet.AAnet(enc_net, dec_net)

# %%
# train
model.train(data, batch_size=128, num_batches=5000)
# Out:
# Iter [       0] Time [0.1752] loss [0.3346]
# Iter [     500] Time [0.8644] loss [0.0047]
# Iter [    1000] Time [1.5461] loss [0.0043]
# Iter [    1500] Time [2.2170] loss [0.0048]
# Iter [    2000] Time [2.9254] loss [0.0042]
# Iter [    2500] Time [3.6553] loss [0.0044]
# Iter [    3000] Time [4.3162] loss [0.0039]
# Iter [    3500] Time [5.0257] loss [0.0042]
# Iter [    4000] Time [5.6960] loss [0.0039]
# Iter [    4500] Time [6.3557] loss [0.0040]
# Iter [    4999] Time [7.0278] loss [0.0042]
# done.

# %%
loss_data = model.compute_loss(data)
print('loss: %.4f' % loss_data)
# Out:
# loss: 0.0042

# %%
model.plot_at_pca_single(data)

# %%
model.plot_at(data)
